# %% [markdown]
# On order to be able to train with GPU:
# Edit->Notebook Settings->Hardware Accelerator->Select GPU
#
# Execute one cell after the other.
#
# The Dataset has to be uploaded as a .zip File to your Google drive, containing all images and the csv file

# %%
import torch
import torch.nn as nn


class DenseLayer(nn.Module):  # also called bottleneck Layer (Used for DenseNet-BC Variants)
    def __init__(self, in_channels, out_channels):
        super(DenseLayer, self).__init__()

        self.bn1 = nn.BatchNorm2d(in_channels)
        self.relu1 = nn.ReLU(inplace=True)
        self.conv1 = nn.Conv2d(in_channels, out_channels * 4, kernel_size=1, stride=1, padding=0, bias=False)
        # 1x1 kernel hat ko + k*(l-1) input channels, und erzeugt 4*32 outputs, welche zu 3x3 kernel gehen. Dies dient vor allem der Parameterreduzierung
        self.bn2 = nn.BatchNorm2d(out_channels * 4)
        self.relu2 = nn.ReLU(inplace=True)
        self.conv2 = nn.Conv2d(out_channels * 4, out_channels, kernel_size=3, stride=1, padding=1, bias=False)


    def forward(self, x):
        out1 = self.conv1(self.relu1(self.bn1(x)))  # input wird zunächst von 1x1 kernel gefiltert
        out = self.conv2(
            self.relu2(self.bn2(out1)))  # anschließend wird 3x3 kernel genutzt, welcher 32 output channels erzeugt
        return torch.cat([x, out], 1)


class TransitionBlock(nn.Module):
    def __init__(self, in_channels, out_channels):
        super(TransitionBlock, self).__init__()
                
        self.bn = nn.BatchNorm2d(in_channels)
        self.relu = nn.ReLU(inplace=True)
        self.conv = nn.Conv2d(in_channels, out_channels, kernel_size=1, stride=1, padding=0, bias=False)
        self.pool = nn.AvgPool2d(kernel_size=2, stride=2, padding=1)

    def forward(self, x):
        out = self.pool(self.conv(self.relu(self.bn(x))))
        return out


class DenseBlock(nn.Module):
    def __init__(self, layer_size, in_channels,
                 growth_rate):  # growth_rate (k in paper) is equal to amount of output channels for each layer
        super(DenseBlock, self).__init__()

        self.block = []
        for i in range(layer_size):
            self.block.append(DenseLayer(in_channels + i * growth_rate, growth_rate))
            # input = k0 + (l-1)*k, k0 = in_channels, l-1 = i (l = amount of layers before current layer)

        self.block = nn.Sequential(*self.block)

    def forward(self, x):
        out = self.block(x)
        return out


class DenseNet(nn.Module):
    def __init__(self, in_channels=2, layer_size=[8, 8, 8], growth_rate=12, additional_neurons=8):
        super(DenseNet, self).__init__()

        self.out_channels = 2 * growth_rate  # for k = 32 ->  64
        self.in_channels = 0  # used later

        # First Convolution
        self.conv1 = nn.Conv2d(in_channels, self.out_channels, kernel_size=3, stride=2, padding=1, bias=False)
        self.batchnorm1 = nn.BatchNorm2d(self.out_channels)
        self.relu1 = nn.ReLU(inplace=True)

        #FirstDenseBlock
        self.in_channels = self.out_channels #2*growth_rate -> 64
        self.out_channels = growth_rate
        self.DenseBlock1 = DenseBlock(layer_size[0], self.in_channels, growth_rate)  # 6 Denselayer

        # First Transition Layer
        self.in_channels = self.in_channels + growth_rate * layer_size[0]  # 256
        self.out_channels = int(self.in_channels / 2)  # 128
        self.TransitionLayer1 = TransitionBlock(self.in_channels, self.out_channels)

        #Second DenseBlock
        self.in_channels = self.out_channels  #128 in channels
        self.out_channels = growth_rate
        self.DenseBlock2 = DenseBlock(layer_size[1], self.in_channels, growth_rate)  # 12 Denselayer

        # Second Transition Layer
        self.in_channels = self.in_channels + growth_rate * layer_size[1]  # 512
        self.out_channels = int(self.in_channels / 2)  # 256
        self.TransitionLayer2 = TransitionBlock(self.in_channels, self.out_channels)

        #Third DenseBlock
        self.in_channels = self.out_channels  # 256 in channels
        self.out_channels = growth_rate
        self.DenseBlock3 = DenseBlock(layer_size[2], self.in_channels, growth_rate)  # 24 Denselayer

        self.global_avg_pool = nn.AvgPool2d(kernel_size=(12, 13), stride=1,
                                            padding=0)  # kernel size of 3x2 depends on input size of image!!!!

        self.in_channels = self.in_channels + growth_rate * layer_size[2]  # 1024
        self.batchnorm2 = nn.BatchNorm2d(self.in_channels)

        #fully connected layer
        self.in_channels = self.in_channels + additional_neurons
        self.fully_connected1 = nn.Linear(self.in_channels, 182)
        self.fully_connected2 = nn.Linear(self.in_channels, 4)
        # in_features = 1024 + additional neurons used as input, output = 3 (steering, acceleration, brake)
        self.sigmoid = nn.Sigmoid()
        
        #initialization of all weights
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.constant_(m.bias, 0)

    def forward(self, x, add_input):
        #x = Tensor of Image (96*85*in_channels -> specified in constructor of DenseNet), add_input = List of other Inputs)
        x = self.relu1(self.batchnorm1(self.conv1(x)))
        x = self.TransitionLayer1(self.DenseBlock1(x))
        x = self.TransitionLayer2(self.DenseBlock2(x))
        x = self.DenseBlock3(x)
        x = self.global_avg_pool(x)
        x = self.batchnorm2(x)
        x = torch.flatten(x, 1)
        if not torch.cuda.is_available():
            add_input = torch.Tensor(add_input)
        add_input = torch.squeeze(add_input, 0)
        x = torch.squeeze(x, 0)

        if len(add_input.size()) > 1:  #checks if a is passed as batch or single value
            x = torch.cat((x, add_input), 1)      #concatenate tensor x and a along dimension 1, since dimension zero is reserved by batch
        else:
            x = torch.cat((x, add_input), 0)      #concatenate tensor x and a along dimension 0 (in evaluation mode)

        output = self.fully_connected1(x)
        output = self.fully_connected2(x)
        output = self.sigmoid(output)
        return output
    

def count_parameters(model):        #Function to count learnable parameters of model
    return sum(p.numel() for p in model.parameters() if p.requires_grad)


CNN = DenseNet()
CNN.eval()  # activate evaluation mode
print("Amount of learnable Parameters: ", count_parameters(CNN))
# Out:
# Amount of learnable Parameters:  296706

# %%
#make sure to execute this code snipped before you start training

from google.colab import drive

#you will be asked to enter the authorization code of your google account - only valid for one session
#Go to this URL in a browser in order to obtain your key: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.activity.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fexperimentsandconfigs%20https%3a%2f%2fwww.googleapis.com%2fauth%2fphotos.native&response_type=code
drive.mount('/content/gdrive')

"""
gdrive can now be accessed under: 
content/gdrive/MyDrive/
"""
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).
# '\ngdrive can now be accessed under: \ncontent/gdrive/MyDrive/\n'

# %%
#google drive connection - Paste the path where you stored the zip on your drive here
#go to files (folder on the left side) -> gdrive ->... and navigate to the training data folder (zip file)
#copy the path of the folder and the csv file (by clicking on the three dots) and paste them here

# !unzip "/content/gdrive/MyDrive/training_v1_processed_balanced_33k/training.zip"

#files will now be unzipped and stored locally on google colab -> increases speed drastically
# Out:
# Die letzten 5000 Zeilen der Streamingausgabe wurden abgeschnitten.
#   inflating: training/processed_1620489738_304.png
#   inflating: training/processed_1620489738_307.png
#   inflating: training/processed_1620489738_309.png
#   inflating: training/processed_1620489738_31.png
#  extracting: training/processed_1620489738_311.png
#  extracting: training/processed_1620489738_312.png
#   inflating: training/processed_1620489738_314.png
#   inflating: training/processed_1620489738_320.png
#   inflating: training/processed_1620489738_323.png
#  extracting: training/processed_1620489738_335.png
#  extracting: training/processed_1620489738_336.png
#   inflating: training/processed_1620489738_338.png
#   inflating: training/processed_1620489738_346.png
#  extracting: training/processed_1620489738_348.png
#  extracting: training/processed_1620489738_350.png
#  extracting: training/processed_1620489738_353.png
#  extracting: training/processed_1620489738_362.png
#  extracting: training/processed_1620489738_364.png
#   inflating: training/processed_1620489738_372.png
#   inflating: training/processed_1620489738_377.png
#   inflating: training/processed_1620489738_379.png
#   inflating: training/processed_1620489738_384.png
#   inflating: training/processed_1620489738_387.png
#   inflating: training/processed_1620489738_389.png
#   inflating: training/processed_1620489738_391.png
#   inflating: training/processed_1620489738_392.png
#   inflating: training/processed_1620489738_401.png
#   inflating: training/processed_1620489738_402.png
#   inflating: training/processed_1620489738_404.png
#   inflating: training/processed_1620489738_41.png
#  extracting: training/processed_1620489738_412.png
#  extracting: training/processed_1620489738_414.png
#  extracting: training/processed_1620489738_417.png
#  extracting: training/processed_1620489738_419.png
#   inflating: training/processed_1620489738_42.png
#  extracting: training/processed_1620489738_420.png
#  extracting: training/processed_1620489738_423.png
#  extracting: training/processed_1620489738_425.png
#  extracting: training/processed_1620489738_426.png
#  extracting: training/processed_1620489738_428.png
#  extracting: training/processed_1620489738_430.png
#  extracting: training/processed_1620489738_433.png
#  extracting: training/processed_1620489738_440.png
#   inflating: training/processed_1620489738_443.png
#   inflating: training/processed_1620489738_446.png
#   inflating: training/processed_1620489738_448.png
#   inflating: training/processed_1620489738_455.png
#   inflating: training/processed_1620489738_456.png
#   inflating: training/processed_1620489738_458.png
#   inflating: training/processed_1620489738_464.png
#   inflating: training/processed_1620489738_467.png
#   inflating: training/processed_1620489738_469.png
#   inflating: training/processed_1620489738_471.png
#   inflating: training/processed_1620489738_472.png
#  extracting: training/processed_1620489738_481.png
#  extracting: training/processed_1620489738_482.png
#  extracting: training/processed_1620489738_494.png
#  extracting: training/processed_1620489738_497.png
#  extracting: training/processed_1620489738_499.png
#   inflating: training/processed_1620489738_5.png
#   inflating: training/processed_1620489738_504.png
#   inflating: training/processed_1620489738_507.png
#   inflating: training/processed_1620489738_509.png
#   inflating: training/processed_1620489738_511.png
#   inflating: training/processed_1620489738_512.png
#   inflating: training/processed_1620489738_520.png
#   inflating: training/processed_1620489738_523.png
#   inflating: training/processed_1620489738_533.png
#   inflating: training/processed_1620489738_535.png
#   inflating: training/processed_1620489738_536.png
#   inflating: training/processed_1620489738_537.png
#   inflating: training/processed_1620489738_538.png
#   inflating: training/processed_1620489738_540.png
#  extracting: training/processed_1620489738_543.png
#  extracting: training/processed_1620489738_545.png
#  extracting: training/processed_1620489738_546.png
#  extracting: training/processed_1620489738_548.png
#  extracting: training/processed_1620489738_550.png
#  extracting: training/processed_1620489738_553.png
#  extracting: training/processed_1620489738_555.png
#  extracting: training/processed_1620489738_556.png
#  extracting: training/processed_1620489738_558.png
#  extracting: training/processed_1620489738_561.png
#  extracting: training/processed_1620489738_562.png
#   inflating: training/processed_1620489738_569.png
#   inflating: training/processed_1620489777_723.png
#   inflating: training/processed_1620489777_726.png
#   inflating: training/processed_1620489777_729.png
#  extracting: training/processed_1620489777_73.png
#   inflating: training/processed_1620489777_730.png
#  extracting: training/processed_1620489777_76.png
#  extracting: training/processed_1620489777_79.png
#  extracting: training/processed_1620489777_80.png
#  extracting: training/processed_1620489777_85.png
#   inflating: training/processed_1620489777_9.png
#  extracting: training/processed_1620489777_93.png
#   inflating: training/processed_1620489777_96.png
#   inflating: training/processed_1620489777_99.png
#   inflating: training/processed_1620489812_102.png
#   inflating: training/processed_1620489812_107.png
#   inflating: training/processed_1620489812_11.png
#   inflating: training/processed_1620489812_111.png
#   inflating: training/processed_1620489812_114.png
#   inflating: training/processed_1620489812_115.png
#   inflating: training/processed_1620489812_124.png
#   inflating: training/processed_1620489812_132.png
#   inflating: training/processed_1620489812_137.png
#   inflating: training/processed_1620489812_138.png
#   inflating: training/processed_1620489812_14.png
#   inflating: training/processed_1620489812_140.png
#   inflating: training/processed_1620489812_141.png
#   inflating: training/processed_1620489812_145.png
#   inflating: training/processed_1620489812_153.png
#   inflating: training/processed_1620489812_156.png
#   inflating: training/processed_1620489812_159.png
#   inflating: training/processed_1620489812_163.png
#   inflating: training/processed_1620489812_166.png
#   inflating: training/processed_1620489812_169.png
#   inflating: training/processed_1620489812_170.png
#   inflating: training/processed_1620489812_175.png
#  extracting: training/processed_1620489812_186.png
#  extracting: training/processed_1620489812_187.png
#  extracting: training/processed_1620489812_188.png
#  extracting: training/processed_1620489812_189.png
#  extracting: training/processed_1620489812_190.png
#  extracting: training/processed_1620489812_191.png
#  extracting: training/processed_1620489812_201.png
#  extracting: training/processed_1620489812_204.png
#  extracting: training/processed_1620489812_205.png
#   inflating: training/processed_1620489812_21.png
#  extracting: training/processed_1620489812_212.png
#  extracting: training/processed_1620489812_217.png
#  extracting: training/processed_1620489812_218.png
#  extracting: training/processed_1620489812_222.png
#   inflating: training/processed_1620489812_228.png
#   inflating: training/processed_1620489812_229.png
#   inflating: training/processed_1620489812_230.png
#   inflating: training/processed_1620489812_231.png
#  extracting: training/processed_1620489812_234.png
#   inflating: training/processed_1620489812_24.png
#   inflating: training/processed_1620489812_243.png
#   inflating: training/processed_1620489812_246.png
#   inflating: training/processed_1620489812_247.png
#   inflating: training/processed_1620489812_250.png
#   inflating: training/processed_1620489812_255.png
#  extracting: training/processed_1620489812_260.png
#   inflating: training/processed_1620489812_273.png
#   inflating: training/processed_1620489812_276.png
#   inflating: training/processed_1620489812_279.png
#   inflating: training/processed_1620489812_285.png
#   inflating: training/processed_1620489812_293.png
#  extracting: training/processed_1620489812_296.png
#  extracting: training/processed_1620489812_298.png
#  extracting: training/processed_1620489812_299.png
#  extracting: training/processed_1620489812_300.png
#  extracting: training/processed_1620489812_304.png
#  extracting: training/processed_1620489812_305.png
#  extracting: training/processed_1620489812_313.png
#  extracting: training/processed_1620489812_316.png
#  extracting: training/processed_1620489812_317.png
#  extracting: training/processed_1620489812_318.png
#  extracting: training/processed_1620489812_319.png
#   inflating: training/processed_1620489812_32.png
#  extracting: training/processed_1620489812_321.png
#  extracting: training/processed_1620489812_322.png
#  extracting: training/processed_1620489812_323.png
#  extracting: training/processed_1620489812_324.png
#  extracting: training/processed_1620489812_326.png
#  extracting: training/processed_1620489812_329.png
#  extracting: training/processed_1620489812_330.png
#  extracting: training/processed_1620489812_335.png
#   inflating: training/processed_1620489812_342.png
#   inflating: training/processed_1620489812_343.png
#   inflating: training/processed_1620489812_347.png
#   inflating: training/processed_1620489812_348.png
#   inflating: training/processed_1620489812_350.png
#   inflating: training/processed_1620489812_351.png
#   inflating: training/processed_1620489812_354.png
#   inflating: training/processed_1620489812_361.png
#   inflating: training/processed_1620489812_364.png
#   inflating: training/processed_1620489812_37.png
#   inflating: training/processed_1620489812_372.png
#   inflating: training/processed_1620489812_377.png
#   inflating: training/processed_1620489812_378.png
#   inflating: training/processed_1620489812_38.png
#   inflating: training/processed_1620489812_381.png
#   inflating: training/processed_1620489812_384.png
#   inflating: training/processed_1620489812_392.png
#   inflating: training/processed_1620489812_397.png
#  extracting: training/processed_1620489812_398.png
#   inflating: training/processed_1620489812_40.png
#   inflating: training/processed_1620489812_400.png
#  extracting: training/processed_1620489812_404.png
#  extracting: training/processed_1620489812_412.png
#   inflating: training/processed_1620489812_419.png
#   inflating: training/processed_1620489812_423.png
#   inflating: training/processed_1620489812_426.png
#   inflating: training/processed_1620489812_429.png
#   inflating: training/processed_1620489812_430.png
#  extracting: training/processed_1620489812_435.png
#  extracting: training/processed_1620489812_437.png
#  extracting: training/processed_1620489812_438.png
#  extracting: training/processed_1620489812_440.png
#  extracting: training/processed_1620489812_442.png
#  extracting: training/processed_1620489812_447.png
#  extracting: training/processed_1620489812_448.png
#   inflating: training/processed_1620489812_449.png
#  extracting: training/processed_1620489812_451.png
#   inflating: training/processed_1620489812_454.png
#  extracting: training/processed_1620489812_460.png
#  extracting: training/processed_1620489812_461.png
#  extracting: training/processed_1620489812_464.png
#  extracting: training/processed_1620489812_465.png
#   inflating: training/processed_1620489812_472.png
#   inflating: training/processed_1620489812_476.png
#  extracting: training/processed_1620489812_477.png
#  extracting: training/processed_1620489812_478.png
#  extracting: training/processed_1620489812_479.png
#  extracting: training/processed_1620489812_480.png
#  extracting: training/processed_1620489812_481.png
#  extracting: training/processed_1620489812_484.png
#  extracting: training/processed_1620489812_485.png
#   inflating: training/processed_1620489812_492.png
#   inflating: training/processed_1620489812_493.png
#  extracting: training/processed_1620489812_497.png
#  extracting: training/processed_1620489812_498.png
#   inflating: training/processed_1620489812_5.png
#  extracting: training/processed_1620489812_501.png
#   inflating: training/processed_1620489812_504.png
#  extracting: training/processed_1620489812_518.png
#  extracting: training/processed_1620489812_522.png
#  extracting: training/processed_1620489812_523.png
#  extracting: training/processed_1620489812_526.png
#  extracting: training/processed_1620489812_527.png
#  extracting: training/processed_1620489812_528.png
#   inflating: training/processed_1620489812_53.png
#   inflating: training/processed_1620490023_133.png
#   inflating: training/processed_1620490023_136.png
#   inflating: training/processed_1620490023_139.png
#   inflating: training/processed_1620490023_141.png
#   inflating: training/processed_1620490023_144.png
#   inflating: training/processed_1620490023_15.png
#   inflating: training/processed_1620490023_152.png
#   inflating: training/processed_1620490023_157.png
#   inflating: training/processed_1620490023_158.png
#   inflating: training/processed_1620490023_167.png
#   inflating: training/processed_1620490023_168.png
#   inflating: training/processed_1620490023_171.png
#   inflating: training/processed_1620490023_174.png
#   inflating: training/processed_1620490023_187.png
#  extracting: training/processed_1620490023_188.png
#  extracting: training/processed_1620490023_189.png
#  extracting: training/processed_1620490023_191.png
#   inflating: training/processed_1620490023_20.png
#  extracting: training/processed_1620490023_200.png
#   inflating: training/processed_1620490023_205.png
#   inflating: training/processed_1620490023_213.png
#   inflating: training/processed_1620490023_216.png
#   inflating: training/processed_1620490023_219.png
#   inflating: training/processed_1620490023_223.png
#   inflating: training/processed_1620490023_226.png
#   inflating: training/processed_1620490023_229.png
#  extracting: training/processed_1620490023_235.png
#  extracting: training/processed_1620490023_240.png
#  extracting: training/processed_1620490023_242.png
#  extracting: training/processed_1620490023_243.png
#  extracting: training/processed_1620490023_245.png
#  extracting: training/processed_1620490023_246.png
#  extracting: training/processed_1620490023_247.png
#  extracting: training/processed_1620490023_248.png
#   inflating: training/processed_1620490023_25.png
#  extracting: training/processed_1620490023_251.png
#  extracting: training/processed_1620490023_254.png
#  extracting: training/processed_1620490023_261.png
#  extracting: training/processed_1620490023_264.png
#  extracting: training/processed_1620490023_265.png
#   inflating: training/processed_1620490023_272.png
#   inflating: training/processed_1620490023_277.png
#   inflating: training/processed_1620490023_278.png
#   inflating: training/processed_1620490023_281.png
#   inflating: training/processed_1620490023_284.png
#   inflating: training/processed_1620490023_285.png
#   inflating: training/processed_1620490023_292.png
#   inflating: training/processed_1620490023_297.png
#   inflating: training/processed_1620490023_298.png
#   inflating: training/processed_1620490023_301.png
#   inflating: training/processed_1620490023_304.png
#   inflating: training/processed_1620490023_305.png
#  extracting: training/processed_1620490023_312.png
#  extracting: training/processed_1620490023_316.png
#  extracting: training/processed_1620490023_317.png
#  extracting: training/processed_1620490023_318.png
#  extracting: training/processed_1620490023_322.png
#  extracting: training/processed_1620490023_327.png
#  extracting: training/processed_1620490023_328.png
#   inflating: training/processed_1620490023_33.png
#  extracting: training/processed_1620490023_331.png
#   inflating: training/processed_1620490023_343.png
#   inflating: training/processed_1620490023_346.png
#   inflating: training/processed_1620490023_349.png
#   inflating: training/processed_1620490023_350.png
#   inflating: training/processed_1620490023_355.png
#   inflating: training/processed_1620490023_36.png
#   inflating: training/processed_1620490023_360.png
#  extracting: training/processed_1620490023_378.png
#  extracting: training/processed_1620490023_379.png
#  extracting: training/processed_1620490023_380.png
#  extracting: training/processed_1620490023_385.png
#   inflating: training/processed_1620490023_39.png
#  extracting: training/processed_1620490023_393.png
#  extracting: training/processed_1620490023_396.png
#  extracting: training/processed_1620490023_399.png
#   inflating: training/processed_1620490023_404.png
#   inflating: training/processed_1620490023_418.png
#   inflating: training/processed_1620490023_422.png
#   inflating: training/processed_1620490023_427.png
#   inflating: training/processed_1620490023_431.png
#   inflating: training/processed_1620490023_434.png
#   inflating: training/processed_1620490023_44.png
#   inflating: training/processed_1620490023_443.png
#   inflating: training/processed_1620490023_449.png
#   inflating: training/processed_1620490023_450.png
#   inflating: training/processed_1620490023_455.png
#   inflating: training/processed_1620490023_460.png
#   inflating: training/processed_1620490023_461.png
#   inflating: training/processed_1620490023_465.png
#   inflating: training/processed_1620490023_473.png
#   inflating: training/processed_1620490023_476.png
#   inflating: training/processed_1620490023_477.png
#   inflating: training/processed_1620490023_478.png
#   inflating: training/processed_1620490023_479.png
#   inflating: training/processed_1620490023_480.png
#   inflating: training/processed_1620490023_481.png
#   inflating: training/processed_1620490023_484.png
#  extracting: training/processed_1620490023_485.png
#  extracting: training/processed_1620490023_493.png
#  extracting: training/processed_1620490023_496.png
#  extracting: training/processed_1620490023_499.png
#  extracting: training/processed_1620490023_500.png
#  extracting: training/processed_1620490023_505.png
#   inflating: training/processed_1620490023_513.png
#   inflating: training/processed_1620490023_516.png
#   inflating: training/processed_1620490023_519.png
#   inflating: training/processed_1620490023_52.png
#   inflating: training/processed_1620490023_523.png
#   inflating: training/processed_1620490023_526.png
#   inflating: training/processed_1620490023_529.png
#   inflating: training/processed_1620490023_530.png
#   inflating: training/processed_1620490023_535.png
#   inflating: training/processed_1620490023_542.png
#  extracting: training/processed_1620490023_548.png
#  extracting: training/processed_1620490023_549.png
#  extracting: training/processed_1620490023_550.png
#  extracting: training/processed_1620490023_551.png
#  extracting: training/processed_1620490023_554.png
#  extracting: training/processed_1620490023_560.png
#  extracting: training/processed_1620490023_561.png
#  extracting: training/processed_1620490023_564.png
#  extracting: training/processed_1620490023_565.png
#   inflating: training/processed_1620490023_57.png
#  extracting: training/processed_1620490023_572.png
#   inflating: training/processed_1620490023_576.png
#   inflating: training/processed_1620490023_577.png
#   inflating: training/processed_1620490023_58.png
#   inflating: training/processed_1620490023_580.png
#   inflating: training/processed_1620490023_581.png
#   inflating: training/processed_1620490023_584.png
#   inflating: training/processed_1620490023_592.png
#   inflating: training/processed_1620490023_597.png
#   inflating: training/processed_1620490023_603.png
#   inflating: training/processed_1620490023_606.png
#   inflating: training/processed_1620490023_609.png
#   inflating: training/processed_1620490023_610.png
#   inflating: training/processed_1620490023_615.png
#   inflating: training/processed_1620490023_62.png
#   inflating: training/processed_1620490023_620.png
#   inflating: training/processed_1620490023_625.png
#  extracting: training/processed_1620490023_633.png
#  extracting: training/processed_1620490023_634.png
#  extracting: training/processed_1620490023_636.png
#  extracting: training/processed_1620490023_637.png
#  extracting: training/processed_1620490023_638.png
#  extracting: training/processed_1620490023_639.png
#  extracting: training/processed_1620490023_640.png
#  extracting: training/processed_1620490023_641.png
#  extracting: training/processed_1620490023_644.png
#  extracting: training/processed_1620490023_652.png
#  extracting: training/processed_1620508953_1869.png
#  extracting: training/processed_1620508953_1870.png
#  extracting: training/processed_1620508953_1871.png
#  extracting: training/processed_1620508953_1872.png
#  extracting: training/processed_1620508953_1875.png
#   inflating: training/processed_1620508953_188.png
#  extracting: training/processed_1620508953_1883.png
#  extracting: training/processed_1620508953_1886.png
#  extracting: training/processed_1620508953_1889.png
#  extracting: training/processed_1620508953_1890.png
#  extracting: training/processed_1620508953_1895.png
#  extracting: training/processed_1620508953_1903.png
#  extracting: training/processed_1620508953_1906.png
#  extracting: training/processed_1620508953_1909.png
#  extracting: training/processed_1620508953_1910.png
#  extracting: training/processed_1620508953_1915.png
#  extracting: training/processed_1620508953_1920.png
#  extracting: training/processed_1620508953_1939.png
#  extracting: training/processed_1620508953_1941.png
#  extracting: training/processed_1620508953_1944.png
#  extracting: training/processed_1620508953_1952.png
#  extracting: training/processed_1620508953_1957.png
#  extracting: training/processed_1620508953_1958.png
#  extracting: training/processed_1620508953_1962.png
#  extracting: training/processed_1620508953_1968.png
#  extracting: training/processed_1620508953_1969.png
#  extracting: training/processed_1620508953_1970.png
#  extracting: training/processed_1620508953_1974.png
#  extracting: training/processed_1620508953_1982.png
#  extracting: training/processed_1620508953_1983.png
#  extracting: training/processed_1620508953_1986.png
#  extracting: training/processed_1620508953_1987.png
#  extracting: training/processed_1620508953_1988.png
#   inflating: training/processed_1620508953_20.png
#   inflating: training/processed_1620508953_200.png
#  extracting: training/processed_1620508953_2001.png
#  extracting: training/processed_1620508953_2004.png
#  extracting: training/processed_1620508953_2012.png
#   inflating: training/processed_1620508953_2017.png
#   inflating: training/processed_1620508953_2018.png
#   inflating: training/processed_1620508953_2028.png
#  extracting: training/processed_1620508953_2029.png
#  extracting: training/processed_1620508953_2030.png
#  extracting: training/processed_1620508953_2031.png
#  extracting: training/processed_1620508953_2043.png
#  extracting: training/processed_1620508953_2046.png
#  extracting: training/processed_1620508953_205.png
#  extracting: training/processed_1620508953_2050.png
#  extracting: training/processed_1620508953_2054.png
#  extracting: training/processed_1620508953_2055.png
#  extracting: training/processed_1620508953_2060.png
#   inflating: training/processed_1620508953_2065.png
#   inflating: training/processed_1620508953_2073.png
#   inflating: training/processed_1620508953_2079.png
#   inflating: training/processed_1620508953_2080.png
#   inflating: training/processed_1620508953_2085.png
#   inflating: training/processed_1620508953_2093.png
#   inflating: training/processed_1620508953_2099.png
#   inflating: training/processed_1620508953_2100.png
#   inflating: training/processed_1620508953_2105.png
#   inflating: training/processed_1620508953_2112.png
#   inflating: training/processed_1620508953_2113.png
#   inflating: training/processed_1620508953_2116.png
#   inflating: training/processed_1620508953_2119.png
#   inflating: training/processed_1620508953_2123.png
#   inflating: training/processed_1620508953_2129.png
#  extracting: training/processed_1620508953_213.png
#   inflating: training/processed_1620508953_2130.png
#   inflating: training/processed_1620508953_2135.png
#  extracting: training/processed_1620508953_2142.png
#  extracting: training/processed_1620508953_2143.png
#  extracting: training/processed_1620508953_2145.png
#  extracting: training/processed_1620508953_2146.png
#  extracting: training/processed_1620508953_2147.png
#  extracting: training/processed_1620508953_2148.png
#  extracting: training/processed_1620508953_2151.png
#  extracting: training/processed_1620508953_2154.png
#  extracting: training/processed_1620508953_216.png
#  extracting: training/processed_1620508953_2161.png
#  extracting: training/processed_1620508953_2164.png
#   inflating: training/processed_1620508953_2178.png
#  extracting: training/processed_1620508953_218.png
#   inflating: training/processed_1620508953_2181.png
#  extracting: training/processed_1620508953_219.png
#   inflating: training/processed_1620508953_2192.png
#   inflating: training/processed_1620508953_2198.png
#   inflating: training/processed_1620508953_226.png
#   inflating: training/processed_1620508953_227.png
#   inflating: training/processed_1620508953_229.png
#   inflating: training/processed_1620508953_242.png
#   inflating: training/processed_1620508953_247.png
#   inflating: training/processed_1620508953_25.png
#  extracting: training/processed_1620508953_251.png
#  extracting: training/processed_1620508953_253.png
#  extracting: training/processed_1620508953_254.png
#  extracting: training/processed_1620508953_261.png
#  extracting: training/processed_1620508953_264.png
#   inflating: training/processed_1620508953_278.png
#   inflating: training/processed_1620508953_280.png
#   inflating: training/processed_1620508953_281.png
#   inflating: training/processed_1620508953_284.png
#   inflating: training/processed_1620508953_292.png
#  extracting: training/processed_1620508953_298.png
#  extracting: training/processed_1620508953_301.png
#  extracting: training/processed_1620508953_303.png
#  extracting: training/processed_1620508953_304.png
#  extracting: training/processed_1620508953_305.png
#  extracting: training/processed_1620508953_312.png
#  extracting: training/processed_1620508953_317.png
#  extracting: training/processed_1620508953_318.png
#  extracting: training/processed_1620508953_328.png
#   inflating: training/processed_1620508953_33.png
#  extracting: training/processed_1620508953_331.png
#  extracting: training/processed_1620508953_334.png
#  extracting: training/processed_1620508953_342.png
#  extracting: training/processed_1620508953_343.png
#  extracting: training/processed_1620508953_346.png
#   inflating: training/processed_1620508953_350.png
#   inflating: training/processed_1620508953_355.png
#   inflating: training/processed_1620508953_36.png
#   inflating: training/processed_1620508953_361.png
#   inflating: training/processed_1620508953_365.png
#   inflating: training/processed_1620508953_373.png
#   inflating: training/processed_1620508953_376.png
#   inflating: training/processed_1620508953_379.png
#  extracting: training/processed_1620508953_385.png
#   inflating: training/processed_1620508953_39.png
#  extracting: training/processed_1620508953_393.png
#  extracting: training/processed_1620508953_396.png
#  extracting: training/processed_1620508953_398.png
#  extracting: training/processed_1620508953_399.png
#   inflating: training/processed_1620508953_4.png
#  extracting: training/processed_1620508953_401.png
#  extracting: training/processed_1620508953_404.png
#   inflating: training/processed_1620508953_41.png
#   inflating: training/processed_1620508953_412.png
#   inflating: training/processed_1620508953_418.png
#   inflating: training/processed_1620508953_419.png
#   inflating: training/processed_1620508953_422.png
#  extracting: training/processed_1620508953_427.png
#  extracting: training/processed_1620508953_431.png
#  extracting: training/processed_1620508953_434.png
#  extracting: training/processed_1620508953_435.png
#  extracting: training/processed_1620508953_436.png
#  extracting: training/processed_1620508953_443.png
#  extracting: training/processed_1620508953_446.png
#  extracting: training/processed_1620508953_449.png
#  extracting: training/processed_1620508953_450.png
#  extracting: training/processed_1620508953_745.png
#   inflating: training/processed_1620508953_753.png
#   inflating: training/processed_1620508953_759.png
#  extracting: training/processed_1620508953_763.png
#  extracting: training/processed_1620508953_766.png
#  extracting: training/processed_1620508953_770.png
#  extracting: training/processed_1620508953_775.png
#  extracting: training/processed_1620508953_783.png
#  extracting: training/processed_1620508953_786.png
#  extracting: training/processed_1620508953_789.png
#  extracting: training/processed_1620508953_790.png
#  extracting: training/processed_1620508953_795.png
#  extracting: training/processed_1620508953_802.png
#  extracting: training/processed_1620508953_808.png
#  extracting: training/processed_1620508953_811.png
#  extracting: training/processed_1620508953_82.png
#  extracting: training/processed_1620508953_821.png
#  extracting: training/processed_1620508953_824.png
#   inflating: training/processed_1620508953_832.png
#   inflating: training/processed_1620508953_837.png
#   inflating: training/processed_1620508953_838.png
#   inflating: training/processed_1620508953_840.png
#   inflating: training/processed_1620508953_845.png
#   inflating: training/processed_1620508953_853.png
#   inflating: training/processed_1620508953_859.png
#   inflating: training/processed_1620508953_863.png
#   inflating: training/processed_1620508953_866.png
#   inflating: training/processed_1620508953_869.png
#  extracting: training/processed_1620508953_87.png
#   inflating: training/processed_1620508953_870.png
#   inflating: training/processed_1620508953_875.png
#  extracting: training/processed_1620508953_88.png
#   inflating: training/processed_1620508953_883.png
#   inflating: training/processed_1620508953_886.png
#   inflating: training/processed_1620508953_889.png
#   inflating: training/processed_1620508953_890.png
#   inflating: training/processed_1620508953_895.png
#  extracting: training/processed_1620508953_909.png
#  extracting: training/processed_1620508953_91.png
#  extracting: training/processed_1620508953_911.png
#  extracting: training/processed_1620508953_915.png
#  extracting: training/processed_1620508953_920.png
#   inflating: training/processed_1620508953_921.png
#   inflating: training/processed_1620508953_924.png
#   inflating: training/processed_1620508953_925.png
#  extracting: training/processed_1620508953_933.png
#  extracting: training/processed_1620508953_936.png
#  extracting: training/processed_1620508953_94.png
#  extracting: training/processed_1620508953_943.png
#  extracting: training/processed_1620508953_944.png
#  extracting: training/processed_1620508953_945.png
#  extracting: training/processed_1620508953_946.png
#  extracting: training/processed_1620508953_952.png
#  extracting: training/processed_1620508953_957.png
#  extracting: training/processed_1620508953_958.png
#   inflating: training/processed_1620508953_962.png
#   inflating: training/processed_1620508953_967.png
#   inflating: training/processed_1620508953_970.png
#   inflating: training/processed_1620508953_971.png
#   inflating: training/processed_1620508953_974.png
#   inflating: training/processed_1620508953_982.png
#   inflating: training/processed_1620508953_987.png
#   inflating: training/processed_1620508953_991.png
#  extracting: training/processed_1620508953_994.png
#  extracting: training/processed_1620508953_999.png

# %%
import torch
import os
import pandas as pd
from skimage import io
import numpy as np
import matplotlib.pyplot as plt
from torch.utils.data import Dataset, DataLoader

# Ignore warnings
import warnings
warnings.filterwarnings("ignore")
print("all libraries are imported successfully...")

csv_path = "/content/training/labels.csv"      #provide csv path (same name as zipped folder, but now locally, not on drive)
root_dir = "/content/training"                 #provide root dir (same name as zipped folder, but now locally, not on drive)
print(csv_path)
print(root_dir)
# create a dataset class
# torch.utils.data.Dataset is an abstract clas representing a dataset
class SteeringCommands(Dataset): 
    """ Steering Commands dataset """

    def __init__(self, csv_file, root_dir, transform=None): 
        """
            Args:
                csv_file (string): Path to the csv file with annotations.
                root_dir (string): Directory with all the images.
                transform (callable, optional): Optional transform to be applied
                on a sample.
        """
        self.label_file = pd.read_csv(csv_file)
        self.root_dir = root_dir
        self.transforms = transform

    def __len__(self): 
        return len(self.label_file)

    def __getitem__(self, idx): 
        if torch.is_tensor(idx): 
            idx = idx.tolist()

        img_name = os.path.join(self.root_dir, self.label_file.iloc[idx,11])
        image = io.imread(img_name)
        image = image[:,:,0:2]      #remove blue color channel from image
        commands = self.label_file.iloc[idx, 8:11]
        commands = np.asarray(commands)
        if commands[0] == 1.0:           #append 0/1 depending on turning key value -> defines input for right key
            commands = np.concatenate(([1.0],commands))
        else:
            commands = np.concatenate(([0.0],commands))
        if commands[1] == -1.0:           #append 0/1 depending on turning key value -> defines input for left key
            commands =  np.concatenate(([1.0],commands))
        else:
            commands = np.concatenate(([0.0],commands))
        commands = np.delete(commands, 2)
        image = image.astype('float')
        input_data = self.label_file.iloc[idx, 0:8]
        input_data = np.asarray(input_data)
        commands = commands.astype('float').reshape(-1)
        input_data = input_data.astype('float').reshape(-1)


        if self.transforms: 
            image = self.transforms(image)
            
        commands = torch.from_numpy(commands)
        input_data = torch.from_numpy(input_data)
        sample = {'image': image, 'input_data' : input_data,'commands': commands}
        return sample

class ToTensor(object):
    """Convert ndarrays in sample to Tensors."""

    def __call__(self, image):

        # swap color axis because
        # numpy image: H x W x C
        # torch image: C X H X W
        image = image.transpose((2, 0, 1))
        image = torch.from_numpy(image)
        return image

# instantiate conversion class
convert_data = ToTensor()       #initialize convert_data class which is used to transpose image in steeringcommands class

#create first dataset containing all images 
transformed_dataset = SteeringCommands(csv_file=csv_path, root_dir=root_dir, transform=convert_data)
#transformed dataset receives csf_file path and image directory path as input, as well as the transform operation defined in the ToTensor() class, which is called for each getitem call


 
    
#ONLY FOR DEBUGGING PURPOSES:

# number of subprocesses to use for data loading
num_workers = 0

# samples per batch to load
batch_size = 4

"""
dataloader = DataLoader(transformed_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)

for i_batch, sample_batched in enumerate(dataloader):
    #print(sample_batched['commands'])
    pass
"""
# Out:
# all libraries are imported successfully...
# /content/training/labels.csv
# /content/training
# "\ndataloader = DataLoader(transformed_dataset, batch_size=batch_size, shuffle=True, num_workers=num_workers)\n\nfor i_batch, sample_batched in enumerate(dataloader):\n    #print(sample_batched['commands'])\n    pass\n"

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import torchvision.transforms as transforms
from torch.utils.data import DataLoader

#----------- Parameters to be adapted! ------------
validation = False   #specify whether validation shall be done
batch_size = 32  #hyper parameter - amount of images in one batch - will be passed to the NN at once
nr_epochs = 30   #hyper parameter - determnies how many times the whole training set gets looped through the Neural Network
calculate_mean_and_std = False    #decide whether mean and std shall be calculated for whole dataset - takes much time on colab
#--------------------------------------------------
print(transformed_dataset)
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")     #check if gpu is available for training

print("Creating Model and Loading Trainingdata")
DenseNet = DenseNet(in_channels=2, layer_size=[8,8,8], growth_rate=12, additional_neurons=8).to(device=device)  #initialize DenseNet - Adapt Parameters!!!
DenseNet = DenseNet.float()     #convert parameters of network to float

#DenseNet.load_state_dict(torch.load("/content/trained_desnenet.pth"))

if torch.cuda.is_available():
    print("Using GPU for training")
    DenseNet = DenseNet.cuda()  #load densenet to gpu if available

DenseNet.train()    #activate train mode for Densenet - Batchnorm activated & allows to pass batches


mean_r = 1.1384    #initialize mean value for red input pixel normalization
mean_g = 194.1198    #initialize mean value for green input pixel normalization
std_r = 16.9998     #initialize standard deviation value for red input pixel normalization
std_g = 108.7109     #initialize standard deviation value for green input pixel normalization

loader = DataLoader(transformed_dataset, batch_size=len(transformed_dataset), num_workers=0)    #create a dataset which contains all elements of dataLoading.dataset, in order to calculate mean and std     

if calculate_mean_and_std == True:
  print("Calculating Mean & Std for Green & Red Pixles")
  for i_batch, sample_batched in enumerate(loader):   #calculate meand and std of the whole training set but individually for each channel and save values in variables
      mean_r = sample_batched['image'][:,0,:,:].mean()
      std_r = sample_batched['image'][:,0,:,:].std()
      mean_g = sample_batched['image'][:,1,:,:].mean()
      std_g = sample_batched['image'][:,1,:,:].std()

print("Mean Value red: ", mean_r,", Mean Value green: ", mean_g)
print("Standard Deviation red: ", std_r, ", Standard Deviation green: ", std_g)  #!make sure to use these values during validation / test!

transform = transforms.Compose(     #create transform operation which substracts mean for each image tensor and divides by std and also contains normal transpose trainformation for image
    [convert_data,
     transforms.Normalize(mean=[mean_r, mean_g], std=[std_r, std_g])])

normalized_data = SteeringCommands(csv_file=csv_path, root_dir=root_dir, transform=transform)    #create new normalized training set

normalized_loader = DataLoader(normalized_data, batch_size=batch_size, shuffle=True, num_workers=0)    #load normalized training set - set hyperparameter batch_size

""" Only for debugging purposes
for i_batch, sample_batched in enumerate(normalized_loader):
    print(i_batch, sample_batched['image'].size(), sample_batched['input_data'].size(),
          sample_batched['commands'].size())
    print(sample_batched['image'][0])
    print("Tpye Image: ",type(sample_batched['image'][0]))
    print("Type Commands:, ", type(sample_batched['commands'][0]))
"""

criterion = nn.BCELoss()    #defines loss function - Loss function used here is binary cross entropy loss (CEL for sigmoid)
if torch.cuda.is_available():
    criterion = nn.BCELoss().cuda()
optimizer = optim.Adam(DenseNet.parameters(), lr=0.001, betas=(0.9, 0.999)) #define optimizer - set hyper parameters lr and betas

if(True):
    print("Starting Training")
    
    for epoch in range(nr_epochs):      #loop which trainis the NN with the normalized dataset "nr_epochs" times. - set hyperparameter nr_epochs 
        
        running_loss = 0    #variable to calculate runnning loss (only for output in console)
        
        for i, data in enumerate(normalized_loader):        #loop which goes through whole normalized dataset once
            if torch.cuda.is_available():
                images = data['image'].cuda()                         #split up data dictionary in images, commands(steering, acceleration,brake) and inputs(speed, abs, gyroscope, steering)
                commands = data['commands'].cuda()
                inputs = data['input_data'].cuda()
            if not torch.cuda.is_available():           #transfer tensors to gpu if available 
                images = data['image']
                commands = data['commands']
                inputs = data['input_data']
            
            optimizer.zero_grad()       #resets all gradients to zero 
            
            outputs = DenseNet(images.float(), inputs.float())  #calculate output of one batch, input tensors have to consist of float numbers
            loss = criterion(outputs.float(), commands.float())     #calculate loss, therefore convert function inputs (output of NN and labels) to float
            loss.backward()     #calculate gradient for each parameter based on loss -> dloss/dx
            
            optimizer.step()    #adapts values of NN
            
            running_loss += loss.item()     #add loss of this batch to running loss in order to calculate mean loss later on
            if i % 50 == 49:    # print every 50 mini-batches
                print('[%d, %5d] loss: %.3f' %
                      (epoch + 1, i + 1, running_loss / 50))   #print running loss on screen
                running_loss = 0.0  #reset running loss
                
        print("Epoch ", epoch + 1, " finished")
    
    print('Finished Training')


normalized_loader_validation = DataLoader(normalized_data, batch_size=1, shuffle=True, num_workers=0)


if(validation == True):
    print("Starting Validation")
    
    running_loss = 0
    
    DenseNet.eval()
    
    with torch.no_grad():
        for i, data in enumerate(normalized_loader_validation):        
            images = data['image']                          #split up data dictionary in images, commands(steering, acceleration,brake) and inputs(speed, abs, gyroscope, steering)
            commands = data['commands']
            inputs = data['input_data']
            if torch.cuda.is_available():           #transfer tensors to gpu if available 
                commands = commands.cuda()
                inputs = inputs.cuda()
                images = images.cuda()
            outputs = DenseNet(images.float(), inputs.float())
            commands = torch.squeeze(commands, 0)   #remove unnessecary dimension form commands tensor size:[1,4] -> size:[4]
            loss = criterion(outputs.float(), commands.float())   
            running_loss += loss.item()                       
            if i % 100 == 99:    # print every 50 mini-batches
                print('loss: %.3f' %
                      (running_loss / 100))
                print("Sample Tensor Output:", outputs)
                print("Sample Desired Output:", commands)
                running_loss = 0.0  
            
    print("Finished Validation")
#save model weights
PATH = './trained_desnenet.pth'         #path were is parameters are stored
#make sure to download the file after training is finished

print("Parameters Saved. Please make sure to download the file")
torch.save(DenseNet.state_dict(), PATH)     #save current state dict of model
# Out:
# <__main__.SteeringCommands object at 0x7fa06e6b3590>
# Creating Model and Loading Trainingdata
# Using GPU for training
# Mean Value red:  1.1384 , Mean Value green:  194.1198
# Standard Deviation red:  16.9998 , Standard Deviation green:  108.7109
# Starting Training
# [1,    50] loss: 0.405
# [1,   100] loss: 0.327
# [1,   150] loss: 0.298
# [1,   200] loss: 0.297
# [1,   250] loss: 0.280
# [1,   300] loss: 0.275
# [1,   350] loss: 0.279
# [1,   400] loss: 0.288
# [1,   450] loss: 0.287
# [1,   500] loss: 0.279
# [1,   550] loss: 0.260
# [1,   600] loss: 0.282
# [1,   650] loss: 0.275
# [1,   700] loss: 0.277
# [1,   750] loss: 0.275
# [1,   800] loss: 0.267
# [1,   850] loss: 0.270
# [1,   900] loss: 0.268
# [1,   950] loss: 0.282
# [1,  1000] loss: 0.278
# [1,  1050] loss: 0.262
# Epoch  1  finished
# [2,    50] loss: 0.249
# [2,   100] loss: 0.273
# [2,   150] loss: 0.262
# [2,   200] loss: 0.259
# [2,   250] loss: 0.254
# [2,   300] loss: 0.266
# [2,   350] loss: 0.265
# [2,   400] loss: 0.264
# [2,   450] loss: 0.267
# [2,   500] loss: 0.255
# [2,   550] loss: 0.254
# [2,   600] loss: 0.252
# [2,   650] loss: 0.264
# [2,   700] loss: 0.255
# [2,   750] loss: 0.266
# [2,   800] loss: 0.257
# [2,   850] loss: 0.254
# [2,   900] loss: 0.258
# [2,   950] loss: 0.246
# [2,  1000] loss: 0.264
# [2,  1050] loss: 0.253
# Epoch  2  finished
# [3,    50] loss: 0.250
# [3,   100] loss: 0.253
# [3,   150] loss: 0.248
# [3,   200] loss: 0.249
# [3,   250] loss: 0.261
# [3,   300] loss: 0.251
# [3,   350] loss: 0.257
# [3,   400] loss: 0.249
